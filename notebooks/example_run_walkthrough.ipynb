# %% [markdown]
# # Example Run Walkthrough\nThis notebook documents how to execute the local end-to-end pipeline and inspect outputs.

# %% [markdown]
# ## Commands\n```bash\nmake sync\nmake test\nmake lint\nmake run\n.venv/bin/python scripts/inspect_outputs.py --sample-size 3\n```

# %% [markdown]
# ## Expected Outcome\n- Bronze, Silver, and Gold directories populated under `data/`.\n- `gold/daily_metrics` contains date-partitioned analytics outputs.
